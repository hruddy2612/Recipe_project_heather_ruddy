# %%
# !pip install jupyter_contrib_nbextensions
# !jupyter contrib nbextensions install --user
# Out:
# ...
#      |████████████████████████████████| 20.9 MB 14.9 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 479 kB 19.8 MB/s eta 0:00:01
# ...
#      |████████████████████████████████| 861 kB 16.8 MB/s eta 0:00:01
# ...
#   Created wheel for jupyter-latex-envs: filename=jupyter_latex_envs-1.4.6-py2.py3-none-any.whl size=963394 sha256=d89bba6619506dd339702e4e0d778315df37d28a22861738332d9af947290979
#   Stored in directory: /Users/heatherruddy/Library/Caches/pip/wheels/4d/ba/f4/b8c0941055519ebc0f27e85bfe2bb223f1a59a3b8bfc5c7515
# ...
#   Created wheel for jupyter-nbextensions-configurator: filename=jupyter_nbextensions_configurator-0.4.1-py2.py3-none-any.whl size=465825 sha256=34ebb7c06dc59b9e5c62de9d7a27982a261666813a321674e59a6e4e8a0b3c47
#   Stored in directory: /Users/heatherruddy/Library/Caches/pip/wheels/e3/3a/b3/a709b437602c3807f079f0c35ccba3e1adf9af6f2e6b0ebfea
# Successfully built jupyter-latex-envs jupyter-nbextensions-configurator
# ...

# %%
import pandas as pd

# %%
#import recipe file
df = pd.read_csv ("recipe list for project.csv")

# %%
df
# Out:
#            Recipe title                                        Ingredients   \
# 0    Breakfast sandwich   1/2 lb sausage, 4 eggs, 4 English muffins, 4 s...
# 1       Mushroom burgers  Burger ingredients:\n3 tbsp olive oil\n1 mediu...
# 2             Fish Tacos  Spice Rub:\n\n1 1/2 teaspoon chili powder\n1 t...
# 3                S’mores  Essential Ingredients:\n1 Box of graham cracke...
# 4  Kale avocado Sandwich  2 leaves of kale\nGrated zest of half a small ...
#
#                                          Directions   Prep time Cook time  \
# 0  At Camp\n\n1. Slice avocado and form the sausa...        10m       15m
# 1  At home:\n\n1. In a large skillet, sauté the o...     2h 30m       10m
# 2  At Camp\n\n1. In a small bowl, stir fish rub s...        20m        8m
# 3  At Camp:\n1. Prep s’more. Break graham cracker...         5m        5m
# 4  At home or at camp:\nTear kale into small piec...  5 minuets         0
#
#    Serves #  Unnamed: 6
# 0  4 people         NaN
# ...
